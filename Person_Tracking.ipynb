# %%
import cv2
# !pip install face_recognition
import face_recognition
input_movie = cv2.VideoCapture("/content/sample_data/New-Json2.mp4")
width = int(input_movie.get(cv2.CAP_PROP_FRAME_WIDTH) + 0.5)
height = int(input_movie.get(cv2.CAP_PROP_FRAME_HEIGHT) + 0.5)
size = (width, height)
fourcc = cv2.VideoWriter_fourcc(*'XVID')
output_movie = cv2.VideoWriter('output.avi', fourcc, 28.0, size)

length = int(input_movie.get(cv2.CAP_PROP_FRAME_COUNT))

image = face_recognition.load_image_file("/content/sample_data/Json1.png")
face_encoding = face_recognition.face_encodings(image)[0]

known_faces = [
face_encoding,
]

# Initialize variables
face_locations = []
face_encodings = []
face_names = []
frame_number = 0

while True:
    print("started")
    # Grab a single frame of video
    ret, frame = input_movie.read()
    frame_number += 1

    # Quit when the input video file ends
    if not ret:
        break

    # Convert the image from BGR color (which OpenCV uses) to RGB color (which face_recognition uses)
    rgb_frame = frame[:, :, ::-1]

    # Find all the faces and face encodings in the current frame of video
    face_locations = face_recognition.face_locations(rgb_frame, model="cnn")
    face_encodings = face_recognition.face_encodings(rgb_frame, face_locations)

    face_names = []
    for face_encoding in face_encodings:
       
        # See if the face is a match for the known face(s)
        match = face_recognition.compare_faces(known_faces, face_encoding, tolerance=0.50)

        name = None
        if match[0]:
            name = "Jason Bourne"

        face_names.append(name)

    # Label the results
    for (top, right, bottom, left), name in zip(face_locations, face_names):
        if not name:
            continue

        # Draw a box around the face
        cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

        # Draw a label with a name below the face
        cv2.rectangle(frame, (left, bottom - 25), (right, bottom), (0, 0, 255), cv2.FILLED)
        font = cv2.FONT_HERSHEY_DUPLEX
        cv2.putText(frame, name, (left + 6, bottom - 6), font, 0.5, (255, 255, 255), 1)

    # Write the resulting image to the output video file
    print("Writing frame {} / {}".format(frame_number, length))
    output_movie.write(frame)
    print("Frame Processing Completed")

# All done!
input_movie.release()
cv2.destroyAllWindows()
# Out:
# ...
# started
# Writing frame 1 / 1221
# Frame Processing Completed
# started
# Writing frame 2 / 1221
# Frame Processing Completed
# started
# Writing frame 3 / 1221
# Frame Processing Completed
# started
# Writing frame 4 / 1221
# Frame Processing Completed
# started
# Writing frame 5 / 1221
# Frame Processing Completed
# started
# Writing frame 6 / 1221
# Frame Processing Completed
# started
# Writing frame 7 / 1221
# Frame Processing Completed
# started
# Writing frame 8 / 1221
# Frame Processing Completed
# started
# Writing frame 9 / 1221
# Frame Processing Completed
# started
# Writing frame 10 / 1221
# Frame Processing Completed
# started
# Writing frame 11 / 1221
# Frame Processing Completed
# started
# Writing frame 12 / 1221
# Frame Processing Completed
# started
# Writing frame 13 / 1221
# Frame Processing Completed
# started
# Writing frame 14 / 1221
# Frame Processing Completed
# started
# Writing frame 15 / 1221
# Frame Processing Completed
# started
# ...
